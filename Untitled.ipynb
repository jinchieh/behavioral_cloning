# %%
import tensorflow as tf
tf.python.control_flow_ops = tf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import SGD, Adam, RMSprop
from keras.utils import np_utils
from keras.models import model_from_json

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
driving_csv = pd.read_csv("data/driving_log.csv")

# Examine data
print("Number of datapoints: %d" % len(driving_csv))

driving_csv.head()
# Out:
# Number of datapoints: 3379
#   /Users/Victor/Documents/Udacity-Selfdriving/IMG/center_2017_02_05_12_11_40_920.jpg  \
# 0  /Users/Victor/Documents/Udacity-Selfdriving/IM...
# 1  /Users/Victor/Documents/Udacity-Selfdriving/IM...
# 2  /Users/Victor/Documents/Udacity-Selfdriving/IM...
# 3  /Users/Victor/Documents/Udacity-Selfdriving/IM...
# 4  /Users/Victor/Documents/Udacity-Selfdriving/IM...
#
#    /Users/Victor/Documents/Udacity-Selfdriving/IMG/left_2017_02_05_12_11_40_920.jpg  \
# 0   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 1   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 2   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 3   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 4   /Users/Victor/Documents/Udacity-Selfdriving/I...
#
#    /Users/Victor/Documents/Udacity-Selfdriving/IMG/right_2017_02_05_12_11_40_920.jpg  \
# 0   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 1   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 2   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 3   /Users/Victor/Documents/Udacity-Selfdriving/I...
# 4   /Users/Victor/Documents/Udacity-Selfdriving/I...
#
#          0   1   0.1   30.19028
# 0  0.00000   1     0   30.19031
# 1  0.00000   1     0   30.19032
# 2  0.00000   1     0   30.19029
# 3  0.00000   1     0   30.19032
# 4 -0.27936   1     0   30.17106

# %%
X_path = [driving_csv.loc[i][0] \
              for i in range(len(driving_csv))]
y = [driving_csv.loc[i][3] \
              for i in range(len(driving_csv))]

# %%
X_images = [mpimg.imread(image_path) for image_path in X_path]

# %%
# View image
print("Images: %d" % len(X_images))
print("Sample image")
plt.imshow(X_images[0])
# X_images[0]

# Check image shape
print("Image shape: ", X_images[0].shape)
# Out:
# Images: 20
# Sample image
# Image shape:  (160, 320, 3)

# %%
## Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_images, y, test_size=0.2, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

X_train = np.array(X_train)
X_test = np.array(X_test)
X_valid = np.array(X_valid)
                  
y_train = np.array(y_train)
y_test = np.array(y_test)
y_valid = np.array(y_valid)

# the data, shuffled and split between train and test sets
X_train = X_train.astype('float32')
X_valid = X_valid.astype('float32')
X_test  = X_test.astype('float32')
X_train /= 255
X_valid /= 255
X_test  /= 255
X_train -= 0.5
X_valid -= 0.5
X_test  -= 0.5

y_train = y_train.astype('float32')
y_valid = y_valid.astype('float32')
y_test  = y_test.astype('float32')

# %%
model = Sequential()
model.add(Convolution2D(160, 3, 3, border_mode='same',
                        input_shape=(160,320,3)))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_5 (Convolution2D)  (None, 160, 320, 160) 4480        convolution2d_input_2[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 160, 320, 160) 0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 158, 318, 32)  46112       activation_6[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 158, 318, 32)  0           convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 79, 159, 32)   0           activation_7[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 79, 159, 32)   0           maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 79, 159, 64)   18496       dropout_4[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 79, 159, 64)   0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 77, 157, 64)   36928       activation_8[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 77, 157, 64)   0           convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)    (None, 38, 78, 64)    0           activation_9[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 38, 78, 64)    0           maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 189696)        0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 512)           97124864    flatten_2[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 512)           0           dense_3[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)              (None, 512)           0           activation_10[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 1)             513         dropout_6[0][0]
# ====================================================================================================
# Total params: 97,231,393
# Trainable params: 97,231,393
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Compile model with adam optimizer and learning rate of .0001
adam = Adam(lr=0.0001)
model.compile(loss='mse',
              optimizer=adam)

# Model will save the weights whenever validation loss improves
checkpoint = ModelCheckpoint(filepath = 'model.h5', verbose = 1, save_best_only=True, monitor='val_loss')

# Discontinue training when validation loss fails to decrease
callback = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# Train model for 20 epochs and a batch size of 128
model.fit(X_train,
        y_train,
        nb_epoch=2,
        verbose=1,
        batch_size=2,
        shuffle=True,
        validation_data=(X_valid, y_valid),
        callbacks=[checkpoint, callback])
# Out:
# Train on 14 samples, validate on 2 samples
# Epoch 1/2
# Epoch 00000: val_loss improved from inf to 0.22761, saving model to model.h5
# 14/14 [==============================] - 221s - loss: 0.1324 - val_loss: 0.2276
# Epoch 2/2
# Epoch 00001: val_loss improved from 0.22761 to 0.02953, saving model to model.h5
# 14/14 [==============================] - 258s - loss: 0.2146 - val_loss: 0.0295

# %%
# Save weights
model.save_weights("model.h5")

#json_string = model.to_json()
#with open("model.json", 'w') as jfile:
#    jfile.write(json_string)
#jfile.close() 


import json
json_string = model.to_json()
with open('model.json', 'w') as f:
    json.dump(json_string, f)

# %%
# Print out summary of the model
model.summary()

# Compile model using Adam optimizer 
# and loss computed by mean squared error
model.compile(loss='mean_squared_error',
              optimizer=Adam(),
              metrics=['accuracy'])

### Model training
history = model.fit(x=X_train, y=y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_valid, y_valid))
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_69 (Convolution2D) (None, 160, 320, 160) 4480        convolution2d_input_24[0][0]
# ____________________________________________________________________________________________________
# activation_81 (Activation)       (None, 160, 320, 160) 0           convolution2d_69[0][0]
# ____________________________________________________________________________________________________
# convolution2d_70 (Convolution2D) (None, 158, 318, 32)  46112       activation_81[0][0]
# ____________________________________________________________________________________________________
# activation_82 (Activation)       (None, 158, 318, 32)  0           convolution2d_70[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_39 (MaxPooling2D)   (None, 79, 159, 32)   0           activation_82[0][0]
# ____________________________________________________________________________________________________
# dropout_59 (Dropout)             (None, 79, 159, 32)   0           maxpooling2d_39[0][0]
# ____________________________________________________________________________________________________
# convolution2d_71 (Convolution2D) (None, 79, 159, 64)   18496       dropout_59[0][0]
# ____________________________________________________________________________________________________
# activation_83 (Activation)       (None, 79, 159, 64)   0           convolution2d_71[0][0]
# ____________________________________________________________________________________________________
# convolution2d_72 (Convolution2D) (None, 77, 157, 64)   36928       activation_83[0][0]
# ____________________________________________________________________________________________________
# activation_84 (Activation)       (None, 77, 157, 64)   0           convolution2d_72[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_40 (MaxPooling2D)   (None, 38, 78, 64)    0           activation_84[0][0]
# ____________________________________________________________________________________________________
# dropout_60 (Dropout)             (None, 38, 78, 64)    0           maxpooling2d_40[0][0]
# ____________________________________________________________________________________________________
# flatten_24 (Flatten)             (None, 189696)        0           dropout_60[0][0]
# ____________________________________________________________________________________________________
# dense_44 (Dense)                 (None, 512)           97124864    flatten_24[0][0]
# ____________________________________________________________________________________________________
# activation_85 (Activation)       (None, 512)           0           dense_44[0][0]
# ____________________________________________________________________________________________________
# dropout_61 (Dropout)             (None, 512)           0           activation_85[0][0]
# ____________________________________________________________________________________________________
# dense_45 (Dense)                 (None, 1)             513         dropout_61[0][0]
# ====================================================================================================
# Total params: 97,231,393
# Trainable params: 97,231,393
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# Train on 2432 samples, validate on 271 samples
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     998       # Ensure any changes to the graph are reflected in the runtime.
# --> 999       self._extend_graph()
#    1000       with errors.raise_exception_on_not_ok_status() as status:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1047           tf_session.TF_ExtendGraph(
# -> 1048               self._session, graph_def.SerializeToString(), status)
#    1049         self._opened = True
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# InvalidArgumentError: Node 'sub_724': Unknown input node 'add_661'
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-78-44bd4d0826ba> in <module>()
#      11 history = model.fit(x=X_train, y=y_train,
#      12                     batch_size=batch_size, nb_epoch=nb_epoch,
# ---> 13                     verbose=1, validation_data=(X_valid, y_valid))
#      14 score = model.evaluate(X_test, y_test, verbose=0)
#      15 print('Test score:', score[0])
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1151                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1152                               callback_metrics=callback_metrics,
# -> 1153                               initial_epoch=initial_epoch)
#    1154
#    1155     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     851                 batch_logs['size'] = len(batch_ids)
#     852                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 853                 outs = f(ins_batch)
#     854                 if not isinstance(outs, list):
#     855                     outs = [outs]
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1886                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    1887             feed_dict[tensor] = value
# -> 1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
#    1890                               feed_dict=feed_dict)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     116         session = _SESSION
#     117     if not _MANUAL_VAR_INIT:
# --> 118         _initialize_variables()
#     119     return session
#     120
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _initialize_variables()
#     268         sess = get_session()
#     269         if hasattr(tf, 'variables_initializer'):
# --> 270             sess.run(tf.variables_initializer(uninitialized_variables))
#     271         else:
#     272             sess.run(tf.initialize_variables(uninitialized_variables))
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1032         except KeyError:
#    1033           pass
# -> 1034       raise type(e)(node_def, op, message)
#    1035
#    1036   def _extend_graph(self):
#
# InvalidArgumentError: Node 'sub_724': Unknown input node 'add_661'

# %%
model = Sequential()
model.add(Convolution2D(160, 3, 3, border_mode='same',
                        input_shape=(160,320,3)))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

batch_size = 50
nb_epoch = 10
model_fit = model.fit(X_train,y_train,batch_size=batch_size,nb_epoch=nb_epoch)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     998       # Ensure any changes to the graph are reflected in the runtime.
# --> 999       self._extend_graph()
#    1000       with errors.raise_exception_on_not_ok_status() as status:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1047           tf_session.TF_ExtendGraph(
# -> 1048               self._session, graph_def.SerializeToString(), status)
#    1049         self._opened = True
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# InvalidArgumentError: Node 'cond_40/Switch': Unknown input node 'keras_learning_phase'
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-49-276b60bfb5bf> in <module>()
#      24 batch_size = 50
#      25 nb_epoch = 10
# ---> 26 model_fit = model.fit(X_train,y_train,batch_size=batch_size,nb_epoch=nb_epoch)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1151                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1152                               callback_metrics=callback_metrics,
# -> 1153                               initial_epoch=initial_epoch)
#    1154
#    1155     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     851                 batch_logs['size'] = len(batch_ids)
#     852                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 853                 outs = f(ins_batch)
#     854                 if not isinstance(outs, list):
#     855                     outs = [outs]
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1886                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    1887             feed_dict[tensor] = value
# -> 1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
#    1890                               feed_dict=feed_dict)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     116         session = _SESSION
#     117     if not _MANUAL_VAR_INIT:
# --> 118         _initialize_variables()
#     119     return session
#     120
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _initialize_variables()
#     268         sess = get_session()
#     269         if hasattr(tf, 'variables_initializer'):
# --> 270             sess.run(tf.variables_initializer(uninitialized_variables))
#     271         else:
#     272             sess.run(tf.initialize_variables(uninitialized_variables))
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1032         except KeyError:
#    1033           pass
# -> 1034       raise type(e)(node_def, op, message)
#    1035
#    1036   def _extend_graph(self):
#
# InvalidArgumentError: Node 'cond_40/Switch': Unknown input node 'keras_learning_phase'

# %%
# Out:
# Train on 2736 samples, validate on 305 samples
# Epoch 1/1
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     998       # Ensure any changes to the graph are reflected in the runtime.
# --> 999       self._extend_graph()
#    1000       with errors.raise_exception_on_not_ok_status() as status:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1047           tf_session.TF_ExtendGraph(
# -> 1048               self._session, graph_def.SerializeToString(), status)
#    1049         self._opened = True
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# InvalidArgumentError: Node 'cond_6/Switch': Unknown input node 'keras_learning_phase'
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-29-18c7969750c3> in <module>()
#      14               validation_split=0.1,
#      15               # validation_data=(X_test, y_test),
# ---> 16               shuffle=True)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1151                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1152                               callback_metrics=callback_metrics,
# -> 1153                               initial_epoch=initial_epoch)
#    1154
#    1155     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     851                 batch_logs['size'] = len(batch_ids)
#     852                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 853                 outs = f(ins_batch)
#     854                 if not isinstance(outs, list):
#     855                     outs = [outs]
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1886                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    1887             feed_dict[tensor] = value
# -> 1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
#    1890                               feed_dict=feed_dict)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     116         session = _SESSION
#     117     if not _MANUAL_VAR_INIT:
# --> 118         _initialize_variables()
#     119     return session
#     120
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _initialize_variables()
#     268         sess = get_session()
#     269         if hasattr(tf, 'variables_initializer'):
# --> 270             sess.run(tf.variables_initializer(uninitialized_variables))
#     271         else:
#     272             sess.run(tf.initialize_variables(uninitialized_variables))
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1032         except KeyError:
#    1033           pass
# -> 1034       raise type(e)(node_def, op, message)
#    1035
#    1036   def _extend_graph(self):
#
# InvalidArgumentError: Node 'cond_6/Switch': Unknown input node 'keras_learning_phase'

# %%
# Out:
# Train on 2736 samples, validate on 305 samples
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# InvalidArgumentError: Session was not created with a graph before Run()!
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-26-2b31c82f6189> in <module>()
#       8               validation_split=0.1,
#       9               # validation_data=(X_test, y_test),
# ---> 10               shuffle=True)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1151                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1152                               callback_metrics=callback_metrics,
# -> 1153                               initial_epoch=initial_epoch)
#    1154
#    1155     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     851                 batch_logs['size'] = len(batch_ids)
#     852                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 853                 outs = f(ins_batch)
#     854                 if not isinstance(outs, list):
#     855                     outs = [outs]
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1888         session = get_session()
#    1889         updated = session.run(self.outputs + [self.updates_op],
# -> 1890                               feed_dict=feed_dict)
#    1891         return updated[:len(self.outputs)]
#    1892
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/Victor/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1032         except KeyError:
#    1033           pass
# -> 1034       raise type(e)(node_def, op, message)
#    1035
#    1036   def _extend_graph(self):
#
# InvalidArgumentError: Session was not created with a graph before Run()!
